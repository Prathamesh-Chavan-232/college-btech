# %%
import pandas as pd

# Reading the CSV file
df = pd.read_csv("Iris.csv")

# Printing top 5 rows
df.head()
data = df.drop_duplicates(subset ="Species",)
data.plot(kind='scatter', x='SepalLengthCm', y='SepalWidthCm') 
plt.show()

# importing packages
import seaborn as sns
import matplotlib.pyplot as plt


sns.countplot(x='Species', data=df, )
plt.show()


#Example 1: Comparing Sepal Length and Sepal Width


sns.scatterplot(x='SepalLengthCm', y='SepalWidthCm',
				hue='Species', data=df, )

# Placing Legend outside the Figure
plt.legend(bbox_to_anchor=(1, 1), loc=2)

plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 11
#       8 data = df.drop_duplicates(subset ="Species",)
#       9 data
# ---> 11 iris.plot(kind='scatter', x='sepal_length', y='sepal_width') ;
#      12 plt.show()
#      14 # importing packages
#
# NameError: name 'iris' is not defined

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
#Example 2: Comparing Petal Length and Petal Width
# importing packages
import seaborn as sns
import matplotlib.pyplot as plt


sns.scatterplot(x='PetalLengthCm', y='PetalWidthCm',
				hue='Species', data=df, )

# Placing Legend outside the Figure
plt.legend(bbox_to_anchor=(1, 1), loc=2)

plt.show()

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
#Let’s plot all the column’s relationships using a pairplot. It can be used for multivariate analysis.
# importing packages
import seaborn as sns
import matplotlib.pyplot as plt


sns.pairplot(df.drop(['Id'], axis = 1),
			hue='Species', height=2)

# %% [markdown]
# ![image.png](data:image/png;base64,...)
